# %% [markdown]
# # User Data ETL
# ## Extract, clean and load User data to SQL Sales database

# %%
import sys
sys.path.append('/Users/ronakasher/Deepa/multinational_retail_data_centralisation')

# %%
from source_code.database_utils import DatabaseConnector
from source_code.data_extraction import DataExtractor
from source_code.data_cleaning import DataCleaning
import pandas as pd

# %% [markdown]
# ## Extract data from SQLAlchemy DB using yaml credentials file

# %%
# Read credentials from yaml file and return dictionary of credentials
connector = DatabaseConnector('../db_creds.yaml')
db_creds = connector.read_db_creds()

# %%
#Initialise and return sqlalchemy db engine
db_engine = connector.init_db_engine()

# %%
#List all tables in DB
table_list = connector.list_db_tables()
print(table_list)
# Out:
# ['legacy_store_details', 'legacy_users', 'orders_table']

# %%
#Extract user database table to pandas DataFrame
extractor = DataExtractor()
user_data = extractor.read_rds_table('legacy_users')
user_data.sample(100)
# Out:
#       first_name    last_name date_of_birth                    company  \
# index
# 568          Roy       Thomas    1988-05-20             Allen and Sons
# 6619        Katy     Röhrdanz    1966-08-07                   Wernecke
# 7675       Katie        Scott    1991-02-01  Davison, Green and Palmer
# 6060     Elliott         Kirk    1950-01-21            Dickinson Group
# 11864      Nelly  Grein Groth    1981-02-22                      Kensy
# ...          ...          ...           ...                        ...
# 12184  Charlotte        Brown    2002-09-01             Thompson-Myers
# 951        Jayne      Vincent    1952-04-24   Wilson, Doyle and Foster
# 3437    Kayleigh      Russell    1969-09-30               Wilson Group
# 15287      Julie        Lewis    2001-02-20             Smith and Sons
# 781      Hermann     Gumprich    1954-12-02                     Hiller
#
#                              email_address  \
# index
# 568                   katherine50@cook.com
# 6619                 gkuehnert@kreusel.net
# 7675             dorothyjackson@walker.org
# 6060                sjohnston@williams.com
# 11864              hans-martin63@butte.com
# ...                                    ...
# 12184                   ellie80@davies.biz
# 951             kimberley11@king-gibbs.com
# 3437   taylorrussell@connolly-matthews.net
# 15287                 iainharper@green.com
# 781           zirmegustav@klingelhoefer.de
#
#                                                  address         country  \
# index
# 568    Flat 95\nChamberlain valley\nNew Oliverside\nO...  United Kingdom
# 6619                   Schwitalallee 77\n97251 Hettstedt         Germany
# 7675         Flat 64z\nO'Connor pass\nMandybury\nM3B 6DJ  United Kingdom
# 6060             07 Norton village\nO'Connorfort\nN9 7AW  United Kingdom
# 11864         Anatolij-Stroh-Platz 86\n39137 Dinkelsbühl         Germany
# ...                                                  ...             ...
# 12184  Studio 8\nJemma dale\nWest Katherineview\nW16 9TJ  United Kingdom
# 951               91 Singh trail\nSchofieldport\nB24 7SR  United Kingdom
# 3437           Flat 6\nHawkins ports\nMyersberg\nN35 1XA  United Kingdom
# 15287    Studio 99\nGemma parkway\nClarkeville\nHP1A 5RU  United Kingdom
# 781              Rouven-Liebelt-Straße 0/6\n84926 Lübeck         Germany
#
#       country_code         phone_number   join_date  \
# index
# 568             GB    +44(0)191 4960408  2013-01-11
# 6619            DE          00462741847  1997-04-30
# 7675            GB   +44(0)808 157 0087  1997-07-05
# 6060            GB          01134960911  2007-08-30
# 11864           DE  +49 (0) 4450 526080  1997-02-17
# ...            ...                  ...         ...
# 12184           GB       +44116 4960558  1996-06-09
# 951             GB          03069990070  2007-12-15
# 3437            GB       +44117 4960572  2002-07-05
# 15287           GB         0141 4960760  1999-04-03
# 781             DE     +49(0)3860 19986  2011-05-15
#
#                                   user_uuid
# index
# 568    792f3252-f82a-4cb9-b350-6a2e5170cef0
# 6619   78b4eef9-a21b-4b30-a85a-a575a8edc93d
# 7675   d3d6e4ee-bfde-4b61-b1b0-02b352b55312
# 6060   b18a1c47-8fae-41ef-a429-ce3c5f19c51f
# 11864  6c0d08c9-f753-4ba9-b90f-e515301c8903
# ...                                     ...
# 12184  1476d07c-25b4-41e4-b866-09d02cd5f3fc
# 951    52a82d6a-2750-4c03-8100-89f4982f584d
# 3437   2774c1fa-91d6-4c34-ab0d-148d188e8027
# 15287  2f7eb4ca-3e98-4ee1-85bb-2bd4f99e4fe6
# 781    3ea1afe6-926f-41e1-ad7c-7961445e9745
#
# [100 rows x 11 columns]

# %%
user_data[user_data.duplicated(subset='user_uuid',keep=False)]
# Out:
#       first_name last_name date_of_birth company email_address address  \
# index
# 867         NULL      NULL          NULL    NULL          NULL    NULL
# 1023        NULL      NULL          NULL    NULL          NULL    NULL
# 1807        NULL      NULL          NULL    NULL          NULL    NULL
# 2103        NULL      NULL          NULL    NULL          NULL    NULL
# 2439        NULL      NULL          NULL    NULL          NULL    NULL
# 6526        NULL      NULL          NULL    NULL          NULL    NULL
# 2764        NULL      NULL          NULL    NULL          NULL    NULL
# 4987        NULL      NULL          NULL    NULL          NULL    NULL
# 5310        NULL      NULL          NULL    NULL          NULL    NULL
# 6927        NULL      NULL          NULL    NULL          NULL    NULL
# 7747        NULL      NULL          NULL    NULL          NULL    NULL
# 10025       NULL      NULL          NULL    NULL          NULL    NULL
# 10237       NULL      NULL          NULL    NULL          NULL    NULL
# 11002       NULL      NULL          NULL    NULL          NULL    NULL
# 11459       NULL      NULL          NULL    NULL          NULL    NULL
# 11615       NULL      NULL          NULL    NULL          NULL    NULL
# 11778       NULL      NULL          NULL    NULL          NULL    NULL
# 11881       NULL      NULL          NULL    NULL          NULL    NULL
# 12110       NULL      NULL          NULL    NULL          NULL    NULL
# 12606       NULL      NULL          NULL    NULL          NULL    NULL
# 13879       NULL      NULL          NULL    NULL          NULL    NULL
#
#       country country_code phone_number join_date user_uuid
# index
# 867      NULL         NULL         NULL      NULL      NULL
# 1023     NULL         NULL         NULL      NULL      NULL
# 1807     NULL         NULL         NULL      NULL      NULL
# 2103     NULL         NULL         NULL      NULL      NULL
# 2439     NULL         NULL         NULL      NULL      NULL
# 6526     NULL         NULL         NULL      NULL      NULL
# 2764     NULL         NULL         NULL      NULL      NULL
# 4987     NULL         NULL         NULL      NULL      NULL
# 5310     NULL         NULL         NULL      NULL      NULL
# 6927     NULL         NULL         NULL      NULL      NULL
# 7747     NULL         NULL         NULL      NULL      NULL
# 10025    NULL         NULL         NULL      NULL      NULL
# 10237    NULL         NULL         NULL      NULL      NULL
# 11002    NULL         NULL         NULL      NULL      NULL
# 11459    NULL         NULL         NULL      NULL      NULL
# 11615    NULL         NULL         NULL      NULL      NULL
# 11778    NULL         NULL         NULL      NULL      NULL
# 11881    NULL         NULL         NULL      NULL      NULL
# 12110    NULL         NULL         NULL      NULL      NULL
# 12606    NULL         NULL         NULL      NULL      NULL
# 13879    NULL         NULL         NULL      NULL      NULL

# %% [markdown]
# ## Clean User data using DataCleaning class from source code

# %%
#Clean user data
clean_user_data = DataCleaning().clean_user_data(user_data)

# %%
#Remove Null rows in cleaned data
clean_user_data.dropna(how='all')
clean_user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15300 entries, 0 to 1249
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     15284 non-null  object
#  1   last_name      15285 non-null  object
#  2   date_of_birth  15284 non-null  object
#  3   company        15284 non-null  object
#  4   email_address  15241 non-null  string
#  5   address        15300 non-null  object
#  6   country        15284 non-null  object
#  7   country_code   15278 non-null  string
#  8   phone_number   15300 non-null  object
#  9   join_date      15284 non-null  object
#  10  user_uuid      15284 non-null  object
# dtypes: object(9), string(2)
# memory usage: 1.4+ MB

# %%
#Upload to sales_data DB (SQL)
upload = DatabaseConnector('../db_creds.yaml')
upload.upload_to_db(clean_user_data,'dim_users')
# Out:
# 300
